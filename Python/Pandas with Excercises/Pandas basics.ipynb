# %% [markdown]
# # What's pandas for?
# If you wnat to explore a dataset, pandas will extract the data from dataset into dataframe - a table then lets you all table manupulations

# %%
#conda install pandas
#pip install pandas

# %%
import pandas as pd
data = {
    'kohli':[45,65,76,100,108],
    'dhoni':[50,66,45,35,70]
}

cricketers = pd.DataFrame(data)
cricketers
# Out:
#    kohli  dhoni
# 0     45     50
# 1     65     66
# 2     76     45
# 3    100     35
# 4    108     70

# %%
data = {
    'oranges':[3,2,0,1],
    'apples':[0,3,7,2]
}

fruits = pd.DataFrame(data)
fruits
# Out:
#    oranges  apples
# 0        3       0
# 1        2       3
# 2        0       7
# 3        1       2

# %%
data = pd.DataFrame(data,index = ['June','July','August','September'])

# %%
data
# Out:
#            oranges  apples
# June             3       0
# July             2       3
# August           0       7
# September        1       2

# %%
data.loc['July']
# Out:
# oranges    2
# apples     3
# Name: July, dtype: int64

# %%
data.iloc[1]
# Out:
# oranges    2
# apples     3
# Name: July, dtype: int64

# %%
data['oranges']
# Out:
# June         3
# July         2
# August       0
# September    1
# Name: oranges, dtype: int64

# %%
data['apples']['August']
# Out:
# 7

# %%
import os
os.listdir()
# Out:
# ['.anaconda',
#  '.android',
#  '.atom',
#  '.conda',
#  '.condarc',
#  '.eclipse',
#  '.Icecream Screen Recorder',
#  '.idlerc',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.ivy2',
#  '.jupyter',
#  '.matplotlib',
#  '.p2',
#  '.sbt',
#  '.scala_history',
#  '.tooling',
#  '.VirtualBox',
#  '3D Objects',
#  'Anaconda3',
#  'AppData',
#  'Application Data',
#  'car_sale.csv',
#  'Contacts',
#  'Cookies',
#  'derby.log',
#  'Desktop',
#  'Documents',
#  'Downloads',
#  'Dropbox',
#  'eclipse',
#  'Favorites',
#  'IdeaProjects',
#  'Intel',
#  'IntelGraphicsProfiles',
#  'Links',
#  'Local Settings',
#  'log',
#  'metastore_db',
#  'MicrosoftEdgeBackups',
#  'Moving average.ipynb',
#  'Music',
#  'My Documents',
#  'NetHood',
#  'NIFTY 50_Data.csv',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{97e24ef6-ff91-11e9-a131-b2b403633aa3}.TxR.0.regtrans-ms',
#  'NTUSER.DAT{97e24ef6-ff91-11e9-a131-b2b403633aa3}.TxR.1.regtrans-ms',
# ...

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 8AA6-5E34
#
#  Directory of C:\Users\Akshara
#
# 05-04-2020  09:42    <DIR>          .
# 05-04-2020  09:42    <DIR>          ..
# 22-03-2020  12:09    <DIR>          .anaconda
# 09-09-2018  12:37    <DIR>          .android
# 28-03-2020  13:09    <DIR>          .conda
# 28-03-2020  13:03                43 .condarc
# 21-03-2020  11:16    <DIR>          .Icecream Screen Recorder
# 29-05-2018  08:16    <DIR>          .idlerc
# 05-04-2020  09:20    <DIR>          .ipynb_checkpoints
# 04-07-2019  22:09    <DIR>          .ipython
# 09-09-2018  14:43    <DIR>          .ivy2
# 11-07-2019  10:35    <DIR>          .jupyter
# 22-01-2020  09:50    <DIR>          .matplotlib
# 09-09-2018  12:57    <DIR>          .sbt
# 28-03-2020  10:49    <DIR>          Anaconda3
# 14-03-2020  08:56    <DIR>          Contacts
# 24-07-2018  11:03               693 derby.log
# 03-04-2020  17:55    <DIR>          Desktop
# ...

# %% [markdown]
# #  methods of reading datas into pandas dataframe

# %%
df=pd.read_csv("car_sale.csv")
df
# Out:
#    Year  Month         Make              Model  Quantity   Pct   Sales
# 0  2007      1  Volkswagen   Volkswagen Passat      1267  10.0  1000.0
# 1  2007      1      Toyota         Toyota Rav4       819   6.5   300.0
# 2  2007      1      Toyota      Toyota Avensis       787   6.2  4000.0
# 3  2007      1  Volkswagen     Volkswagen Golf       720   5.7  5000.0
# 4  2007      1      Toyota      Toyota Corolla       691   5.4  6000.0
# 5  2007      1     Peugeot         Peugeot 307       481   3.8     NaN
# 6  2007      1       Skoda       Skoda Octavia       481   3.8   100.0
# 7  2007      1      Toyota        Toyota Yaris       402   3.2     NaN
# 8  2007      1        Ford          Ford Focus       400   3.2    50.0

# %%
#if index column not required
df=pd.read_csv("car_sale.csv",index_col=0)
df
# Out:
#       Month         Make              Model  Quantity   Pct   Sales
# Year
# 2007      1  Volkswagen   Volkswagen Passat      1267  10.0  1000.0
# 2007      1      Toyota         Toyota Rav4       819   6.5   300.0
# 2007      1      Toyota      Toyota Avensis       787   6.2  4000.0
# 2007      1  Volkswagen     Volkswagen Golf       720   5.7  5000.0
# 2007      1      Toyota      Toyota Corolla       691   5.4  6000.0
# 2007      1     Peugeot         Peugeot 307       481   3.8     NaN
# 2007      1       Skoda       Skoda Octavia       481   3.8   100.0
# 2007      1      Toyota        Toyota Yaris       402   3.2     NaN
# 2007      1        Ford          Ford Focus       400   3.2    50.0

# %%
df.head(2)
# Out:
#       Month         Make              Model  Quantity   Pct   Sales
# Year
# 2007      1  Volkswagen   Volkswagen Passat      1267  10.0  1000.0
# 2007      1      Toyota         Toyota Rav4       819   6.5   300.0

# %%
df.tail(3)
# Out:
#       Month     Make          Model  Quantity  Pct  Sales
# Year
# 2007      1   Skoda   Skoda Octavia       481  3.8  100.0
# 2007      1  Toyota    Toyota Yaris       402  3.2    NaN
# 2007      1    Ford      Ford Focus       400  3.2   50.0

# %%
df.columns
# Out:
# Index(['Month', 'Make', 'Model', 'Quantity', 'Pct', 'Sales'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9 entries, 2007 to 2007
# Data columns (total 6 columns):
# Month       9 non-null int64
# Make        9 non-null object
# Model       9 non-null object
# Quantity    9 non-null int64
# Pct         9 non-null float64
# Sales       7 non-null float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 504.0+ bytes

# %%
df.shape
# Out:
# (9, 6)

# %%
cols = df.columns.values
cols
# Out:
# array(['Month', 'Make', 'Model', 'Quantity', 'Pct', 'Sales'], dtype=object)

# %%
df.rename(columns = {
    "Month":"MONTH",
    "Model":"MODEL",
    "Quantity":"QTY",
    "Pct":"PERCENTAGE",
    "Sales":"SALES"
},inplace = True)
df.columns
# Out:
# Index(['MONTH', 'Make', 'MODEL', 'QTY', 'PERCENTAGE', 'SALES'], dtype='object')

# %%
for i in df:
    print(i)
# Out:
# MONTH
# Make
# MODEL
# QTY
# PERCENTAGE
# SALES

# %%
col_low=[]
for i in df:
    i = i.lower()
    col_low.append(i)
col_low
# Out:
# ['month', 'make', 'model', 'qty', 'percentage', 'sales']

# %%
for i in df.values:
    print(i)
# Out:
# [1 'Volkswagen ' 'Volkswagen Passat' 1267 10.0 1000.0]
# [1 'Toyota ' 'Toyota Rav4' 819 6.5 300.0]
# [1 'Toyota ' 'Toyota Avensis' 787 6.2 4000.0]
# [1 'Volkswagen ' 'Volkswagen Golf' 720 5.7 5000.0]
# [1 'Toyota ' 'Toyota Corolla' 691 5.4 6000.0]
# [1 'Peugeot ' 'Peugeot 307' 481 3.8 nan]
# [1 'Skoda ' 'Skoda Octavia' 481 3.8 100.0]
# [1 'Toyota ' 'Toyota Yaris' 402 3.2 nan]
# [1 'Ford ' 'Ford Focus' 400 3.2 50.0]

# %%
df.loc[(df["MODEL"]=="Ford Focus")]
# Out:
#       MONTH   Make       MODEL  QTY  PERCENTAGE  SALES
# Year
# 2007      1  Ford   Ford Focus  400         3.2   50.0

# %%
for i in df['MODEL']:
    if (type(i) == str):
        print('yes')
# Out:
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes

# %% [markdown]
# # Check Null values

# %%
df.isna().sum()
# Out:
# MONTH         0
# Make          0
# MODEL         0
# QTY           0
# PERCENTAGE    0
# SALES         2
# dtype: int64

# %%
df[df['SALES'].isna()== True]
# Out:
#       MONTH      Make         MODEL  QTY  PERCENTAGE  SALES
# Year
# 2007      1  Peugeot    Peugeot 307  481         3.8    NaN
# 2007      1   Toyota   Toyota Yaris  402         3.2    NaN

# %%
df = df.dropna
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-83-d69b6bc92262> in <module>()
# ----> 1 df = df.dropna
#
# AttributeError: 'function' object has no attribute 'dropna'

# %%
df[df['SALES'].isna()== True]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-82-08ab0ffacc0c> in <module>()
# ----> 1 df[df['SALES'].isna()== True]
#
# TypeError: 'method' object is not subscriptable

# %%
df.describe()
# Out:
#        MONTH          QTY  PERCENTAGE        SALES
# count    9.0     9.000000    9.000000     7.000000
# mean     1.0   672.000000    5.311111  2350.000000
# std      0.0   276.443936    2.174537  2564.013781
# min      1.0   400.000000    3.200000    50.000000
# 25%      1.0   481.000000    3.800000   200.000000
# 50%      1.0   691.000000    5.400000  1000.000000
# 75%      1.0   787.000000    6.200000  4500.000000
# max      1.0  1267.000000   10.000000  6000.000000

# %%
df["MODEL"].value_counts()
# Out:
# Peugeot 307          1
# Toyota Avensis       1
# Volkswagen Passat    1
# Toyota Yaris         1
# Toyota Rav4          1
# Toyota Corolla       1
# Ford Focus           1
# Volkswagen Golf      1
# Skoda Octavia        1
# Name: MODEL, dtype: int64

# %%
df.corr()
# Out:
#             MONTH       QTY  PERCENTAGE     SALES
# MONTH         NaN       NaN         NaN       NaN
# QTY           NaN  1.000000    0.999917  0.078144
# PERCENTAGE    NaN  0.999917    1.000000  0.068048
# SALES         NaN  0.078144    0.068048  1.000000

# %%
cond = df[df['Make']=='Toyota ']
cond
# Out:
#       MONTH     Make           MODEL  QTY  PERCENTAGE   SALES
# Year
# 2007      1  Toyota      Toyota Rav4  819         6.5   300.0
# 2007      1  Toyota   Toyota Avensis  787         6.2  4000.0
# 2007      1  Toyota   Toyota Corolla  691         5.4  6000.0
# 2007      1  Toyota     Toyota Yaris  402         3.2     NaN

# %% [markdown]
# # Duplicates

# %%
duplicate_df = df.append(df)
duplicate_df
# Out:
#       Month         Make              Model  Quantity   Pct   Sales
# Year
# 2007      1  Volkswagen   Volkswagen Passat      1267  10.0  1000.0
# 2007      1      Toyota         Toyota Rav4       819   6.5   300.0
# 2007      1      Toyota      Toyota Avensis       787   6.2  4000.0
# 2007      1  Volkswagen     Volkswagen Golf       720   5.7  5000.0
# 2007      1      Toyota      Toyota Corolla       691   5.4  6000.0
# 2007      1     Peugeot         Peugeot 307       481   3.8     NaN
# 2007      1       Skoda       Skoda Octavia       481   3.8   100.0
# 2007      1      Toyota        Toyota Yaris       402   3.2     NaN
# 2007      1        Ford          Ford Focus       400   3.2    50.0
# 2007      1  Volkswagen   Volkswagen Passat      1267  10.0  1000.0
# 2007      1      Toyota         Toyota Rav4       819   6.5   300.0
# 2007      1      Toyota      Toyota Avensis       787   6.2  4000.0
# 2007      1  Volkswagen     Volkswagen Golf       720   5.7  5000.0
# ...

# %%
duplicate_df.shape
# Out:
# (18, 6)

# %%
duplicate_df = duplicate_df.drop_duplicates(inplace=False)
duplicate_df.shape
# Out:
# (9, 6)

# %%
duplicate_df.drop_duplicates(inplace=True)
duplicate_df.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-53-5b75eace9eba> in <module>()
# ----> 1 duplicate_df.drop_duplicates(inplace=True)
#       2 duplicate_df.shape
#
# AttributeError: 'NoneType' object has no attribute 'drop_duplicates'

# %%
#read raw data from github link
df1=pd.read_csv("https://raw.githubusercontent.com/codeforamerica/ohana-api/master/data/sample-csv/addresses.csv")
df1
# Out:
#     id  location_id                   address_1  address_2  \
# 0    1            1       2600 Middlefield Road        NaN
# 1    2            2            24 Second Avenue        NaN
# 2    3            3            24 Second Avenue        NaN
# 3    4            4            24 Second Avenue        NaN
# 4    5            5            24 Second Avenue        NaN
# 5    6            6           800 Middle Avenue        NaN
# 6    7            7              500 Arbor Road        NaN
# 7    8            8           800 Middle Avenue        NaN
# 8    9            9       2510 Middlefield Road        NaN
# 9   10           10       1044 Middlefield Road        NaN
# 10  11           11         2140 Euclid Avenue.        NaN
# 11  12           12       1044 Middlefield Road  2nd Floor
# 12  13           13         399 Marine Parkway.        NaN
# 13  14           14          660 Veterans Blvd.        NaN
# 14  15           15        1500 Valencia Street        NaN
# ...

# %%
df2 = pd.read_json("https://raw.githubusercontent.com/LearnWebCode/json-example/master/animals-1.json")
df2
# Out:
#                                                foods      name species
# 0  {'likes': ['tuna', 'catnip'], 'dislikes': ['ha...    Meowsy     cat
# 1  {'likes': ['bones', 'carrots'], 'dislikes': ['...     Barky     dog
# 2       {'likes': ['mice'], 'dislikes': ['cookies']}  Purrpaws     cat

# %% [markdown]
# # How to open  a database file

# %%
#pip install pysqlite3
# Out:
# The following command must be run outside of the IPython shell:
#
#     $ pip install pysqlite3
#
# The Python package manager (pip) can only be used from outside of IPython.
# Please reissue the `pip` command in a separate terminal or command prompt.
#
# See the Python documentation for more information on how to install packages:
#
#     https://docs.python.org/3/installing/

# %%
import sqlite3
con = sqlite3.connect('chinook.db')
df3 = pd.read_sql_query("select * from employees",con)

# %%
df3
# Out:
#    EmployeeId  LastName FirstName                Title  ReportsTo  \
# 0           1     Adams    Andrew      General Manager        NaN
# 1           2   Edwards     Nancy        Sales Manager        1.0
# 2           3   Peacock      Jane  Sales Support Agent        2.0
# 3           4      Park  Margaret  Sales Support Agent        2.0
# 4           5   Johnson     Steve  Sales Support Agent        2.0
# 5           6  Mitchell   Michael           IT Manager        1.0
# 6           7      King    Robert             IT Staff        6.0
# 7           8  Callahan     Laura             IT Staff        6.0
#
#              BirthDate             HireDate                      Address  \
# 0  1962-02-18 00:00:00  2002-08-14 00:00:00          11120 Jasper Ave NW
# 1  1958-12-08 00:00:00  2002-05-01 00:00:00                 825 8 Ave SW
# 2  1973-08-29 00:00:00  2002-04-01 00:00:00                1111 6 Ave SW
# 3  1947-09-19 00:00:00  2003-05-03 00:00:00             683 10 Street SW
# ...

# %%
cursor = con.cursor()
cursor.execute("select LastName from employees")
cursor.fetchall()
# Out:
# [('Adams',),
#  ('Edwards',),
#  ('Peacock',),
#  ('Park',),
#  ('Johnson',),
#  ('Mitchell',),
#  ('King',),
#  ('Callahan',)]
